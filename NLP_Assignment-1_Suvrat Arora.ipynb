# %% [markdown]
# # Conversational AI: Natural Language Processing (UCS664)
# # Assignment-1
#
# Suvrat Arora <br>
# 101903331 <br>
# 3CO13 <br>

# %%
#importing nltk
import nltk

#downlading book
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     C:\Users\suvra\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\abc.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     C:\Users\suvra\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\brown.zip.
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     C:\Users\suvra\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\chat80.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     C:\Users\suvra\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     C:\Users\suvra\AppData\Roaming\nltk_data...
# [nltk_data]    |   Unzipping corpora\conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# ...

# %%
#importing everything from nltk.books
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %% [markdown]
# **Q1: Find the collocations in text5**

# %%
from nltk.collocations import *

#bigram collocations
print("Top 10 Bi-Gram Collocations:")
bigram_measures=nltk.collocations.BigramAssocMeasures()
finder=BigramCollocationFinder.from_words(text5)
print(finder.nbest(bigram_measures.pmi,10))

#trigram collocations
print("\nTop 10 Tri-Gram Collocations:")
trigram_measures=nltk.collocations.TrigramAssocMeasures()
finder=TrigramCollocationFinder.from_words(text5)
print(finder.nbest(trigram_measures.pmi,10))
# Out:
# Top 10 Bi-Gram Collocations:
# [('!...', 'lotsa'), ("'n'", 'Cream'), ('*sniffs*', 'ewwwwww'), (',,,,,,,', 'babblein'), ('-s', 'woooohoooo'), ('........................', 'CHATHIDE'), ('..............................', 'Boyz'), ('.45', 'barrel'), ('100%', 'cotton'), ('185', 'pounds')]
#
# Top 10 Tri-Gram Collocations:
# [('..............................', 'Boyz', 'II'), ('220', 'lb', 'spouse'), ('AROUND', 'TELLIN', 'GUYS'), ('ASS', 'GIRL', 'WHEN'), ('BLONDES', 'RIGHT', 'HERE'), ('Books', 'Froogle', 'Groups'), ('Boyz', 'II', 'Men'), ('Burger', 'King', 'especially'), ('Ciara', 'ft.', 'Chamillionaire'), ('Cookies', "'n'", 'Cream')]

# %% [markdown]
# **Q2: Define a variable my_sent to be a list of words. Convert my_sent into string and then split it  as list of words.**

# %%
my_sent=['Hi!','this','is','a','sample','sentence']

# my_sent to string
string = ''
for w in my_sent:
    string=string + w + " "
print("my_sent to string: ", string)    

words = string.split()
print("String to words: ", words)
# Out:
# my_sent to string:  Hi! this is a sample sentence
# String to words:  ['Hi!', 'this', 'is', 'a', 'sample', 'sentence']

# %% [markdown]
# **Q3: Find the index of the word sunset in text9.**

# %%
text9.index('sunset')
# Out:
# 629

# %% [markdown]
# **Q4: Compute the vocabulary of the sentences sent1 ... sent8**

# %%
all=[]
for i in range(1,9):
    k=eval('sent'+str(i))
    for j in k:
      all.append(j)        

unique=[]
for i in all:
    if i not in unique:
        unique.append(i)
        
sorted(unique)
# Out:
# ['!',
#  ',',
#  '-',
#  '.',
#  '1',
#  '25',
#  '29',
#  '61',
#  ':',
#  'ARTHUR',
#  'Call',
#  'Citizens',
#  'Dashwood',
#  'Fellow',
#  'God',
#  'House',
#  'I',
#  'In',
#  'Ishmael',
#  'JOIN',
#  'KING',
#  'MALE',
#  'Nov.',
#  'PMing',
#  'Pierre',
#  'Representatives',
#  'SCENE',
#  'SEXY',
#  'Senate',
#  'Sussex',
#  'The',
#  'Vinken',
#  'Whoa',
#  '[',
#  ']',
#  'a',
#  'and',
#  'as',
#  'attrac',
#  'been',
#  'beginning',
#  'board',
#  'clop',
#  'created',
#  'director',
#  'discreet',
#  'earth',
#  'encounters',
#  'family',
#  'for',
#  'had',
#  'have',
#  'heaven',
#  'in',
#  'join',
#  'lady',
#  'lol',
#  'long',
#  'me',
#  'nonexecutive',
#  'of',
#  'old',
#  'older',
#  'people',
#  'problem',
#  'seeks',
#  'settled',
#  'single',
#  'the',
#  'there',
#  'to',
#  'will',
#  'wind',
#  'with',
#  'years']

# %% [markdown]
# **Q5: What is the difference between the following two lines:** <br>
# sorted(set([w.lower() for w in text1]))
# sorted([w.lower() for w in set(text1)])

# %%
sorted(set([w.lower() for w in text1])) 
#makes the vocabulary of after converting all words to lowercase
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %%
sorted([w.lower() for w in set(text1)])  
#makes the the vocabulary first and then converts all words into lowercase
# Out:
# ['!',
#  '!"',
#  '!"--',
#  "!'",
#  '!\'"',
#  '!)',
#  '!)"',
#  '!*',
#  '!--',
#  '!--"',
#  "!--'",
#  '"',
#  '"\'',
#  '"--',
#  '"...',
#  '";',
#  '$',
#  '&',
#  "'",
#  "',",
#  "',--",
#  "'-",
#  "'--",
#  "';",
#  '(',
#  ')',
#  '),',
#  ')--',
#  ').',
#  ').--',
#  '):',
#  ');',
#  ');--',
#  '*',
#  ',',
#  ',"',
#  ',"--',
#  ",'",
#  ",'--",
#  ',)',
#  ',*',
#  ',--',
#  ',--"',
#  ",--'",
#  '-',
#  '--',
#  '--"',
#  "--'",
#  '--\'"',
#  '--(',
#  '---"',
#  '---,',
#  '.',
#  '."',
#  '."*',
#  '."--',
#  ".'",
#  '.\'"',
#  '.)',
#  '.*',
#  '.*--',
#  '.,',
#  '.--',
#  '.--"',
#  '...',
#  '....',
#  '.]',
#  '000',
#  '1',
#  '10',
#  '100',
#  '101',
#  '102',
#  '103',
#  '104',
#  '105',
#  '106',
#  '107',
#  '108',
#  '109',
#  '11',
#  '110',
#  '111',
#  '112',
#  '113',
#  '114',
#  '115',
#  '116',
#  '117',
#  '118',
#  '119',
#  '12',
#  '120',
#  '121',
#  '122',
#  '123',
#  '124',
#  '125',
#  '126',
#  '127',
#  '128',
#  '129',
#  '13',
# ...

# %% [markdown]
# **Q6: Write the slice expression that extracts the last two words of text2**

# %%
(text2[len(text2)-2:])
# Out:
# ['THE', 'END']

# %% [markdown]
# **Q7: Find all the four-letter words in the Chat Corpus (text5). With the help of a frequency  distribution (FreqDist), show these words in decreasing order of frequency**

# %%
#Finding all four letter words
four_letter_words = (set([w for w in text5 if len(w)==4 and w.isalpha()]))
four_letter_words
# Out:
# {'MORE',
#  'Have',
#  'Good',
#  'bois',
#  'serg',
#  'tits',
#  'hooo',
#  'push',
#  'ohhh',
#  'over',
#  'hope',
#  'home',
#  'hugs',
#  'Room',
#  'puke',
#  'Tell',
#  'arms',
#  'Troy',
#  'heal',
#  'Long',
#  'owww',
#  'kmph',
#  'JUST',
#  'well',
#  'alot',
#  'benz',
#  'yell',
#  'Heya',
#  'heee',
#  'much',
#  'lool',
#  'find',
#  'work',
#  'Come',
#  'none',
#  'hand',
#  'sori',
#  'spit',
#  'loss',
#  'east',
#  'goin',
#  'Joey',
#  'akon',
#  'mean',
#  'town',
#  'ahah',
#  'gold',
#  'hogs',
#  'Hugs',
#  'Jane',
#  'sayn',
#  'haaa',
#  'Phil',
#  'give',
#  'limp',
#  'TIME',
#  'kept',
#  'caca',
#  'moms',
#  'nice',
#  'http',
#  'idea',
#  'mary',
#  'hall',
#  'Save',
#  'boed',
#  'eric',
#  'wins',
#  'cuss',
#  'lust',
#  'drew',
#  'lung',
#  'lame',
#  'slap',
#  'vote',
#  'than',
#  'crib',
#  'toop',
#  'side',
#  'outa',
#  'puff',
#  'half',
#  'JOIN',
#  'wine',
#  'card',
#  'jail',
#  'draw',
#  'guyz',
#  'wall',
#  'ello',
# ...

# %%
#Frequecy Distribution in decreasing order
FreqDist(sorted(four_letter_words))
# Out:
# FreqDist({'AKDT': 1, 'AKST': 1, 'AWAY': 1, 'Ahhh': 1, 'Away': 1, 'Awww': 1, 'Back': 1, 'Been': 1, 'Bone': 1, 'Born': 1, ...})

# %% [markdown]
# **Q8: Use a combination of for and if statements to loop over the words of the movie script for  Monty Python and the Holy Grail (text6) and print all the uppercase words**

# %%
l=[w for w in text6 if w.isupper()]
l
# Out:
# ['SCENE',
#  'KING',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'I',
#  'SOLDIER',
#  'ARTHUR',
#  'I',
#  'I',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'A',
#  'ARTHUR',
#  'SOLDIER',
#  'A',
#  'ARTHUR',
#  'SOLDIER',
#  'ARTHUR',
#  'SOLDIER',
#  'I',
#  'ARTHUR',
#  'I',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'I',
#  'ARTHUR',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SOLDIER',
#  'SCENE',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'CART',
#  'MASTER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CART',
#  'MASTER',
#  'CUSTOMER',
#  'DEAD',
#  'PERSON',
#  'I',
#  'CUSTOMER',
#  'CART',
#  'MASTER',
#  'I',
#  'DEAD',
# ...

# %% [markdown]
# **Q9: Write expressions for finding all words in text6 that meet the following conditions**

# %% [markdown]
# **a. Ending in ize**

# %%
l=[w for w in text6 if w.endswith('ize')]
print(l)
# Out:
# []

# %% [markdown]
# **b. Containing the letter z**

# %%
l=[w for w in text6 if 'z' in w.lower()]
print(l)
# Out:
# ['zone', 'amazes', 'Fetchez', 'Fetchez', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'Zoot', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'ZOOT', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'Zoot', 'AMAZING', 'zoop', 'zoo', 'zhiv', 'frozen', 'zoosh']

# %% [markdown]
# **c. Containing the sequence of letters pt**

# %%
l=[w for w in text6 if 'pt' in w.lower()]
print(l)
# Out:
# ['empty', 'aptly', 'Thpppppt', 'Thppt', 'Thppt', 'empty', 'Thppppt', 'temptress', 'temptation', 'ptoo', 'Chapter', 'excepting', 'Thpppt']

# %% [markdown]
# **d. All lowercase letters except for an initial capital (i.e., titlecase)**

# %%
l=[w for w in text6 if w[0].isupper() and w[1:].islower()]
print(l)
# Out:
# ['Whoa', 'Halt', 'Who', 'It', 'Arthur', 'Uther', 'Pendragon', 'Camelot', 'King', 'Britons', 'Saxons', 'England', 'Pull', 'Patsy', 'We', 'Camelot', 'What', 'Ridden', 'Yes', 'You', 'What', 'You', 'So', 'We', 'Mercea', 'Where', 'We', 'Found', 'In', 'Mercea', 'The', 'What', 'Well', 'The', 'Are', 'Not', 'They', 'What', 'It', 'It', 'It', 'Well', 'Will', 'Arthur', 'Court', 'Camelot', 'Listen', 'In', 'Please', 'Am', 'It', 'African', 'Oh', 'African', 'European', 'That', 'Oh', 'Will', 'Camelot', 'But', 'African', 'Oh', 'So', 'Wait', 'Supposing', 'No', 'Well', 'They', 'What', 'Well', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Bring', 'Ninepence', 'Bring', 'Bring', 'Bring', 'Bring', 'Here', 'Ninepence', 'What', 'Nothing', 'Here', 'Ere', 'He', 'Yes', 'He', 'Well', 'He', 'No', 'You', 'Oh', 'It', 'Oh', 'Well', 'Well', 'He', 'No', 'Robinson', 'They', 'Well', 'Thursday', 'You', 'Look', 'Ah', 'Not', 'See', 'Thursday', 'Right', 'All', 'Who', 'Must', 'Why', 'He', 'King', 'Arthur', '
# ...

# %% [markdown]
# **Q10: Define sent to be the list of words ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']. Now  write code to perform the following tasks:**

# %%
l = ['she', 'sells', 'sea', 'shells', 'by', 'the', 'sea', 'shore']

# %% [markdown]
# **a. Print all words beginning with sh**

# %%
l1 = [w for w in l if w.startswith('sh')]
l1
# Out:
# ['she', 'shells', 'shore']

# %% [markdown]
# **b. Print all words longer than four characters**

# %%
l2 = [w for w in l if len(w)>4]
l2
# Out:
# ['sells', 'shells', 'shore']

# %% [markdown]
# **Q11: What does the following Python code do? sum([len(w) for w in text1]) Can you use it to  work out the average word length of a text?**

# %%
sum([len(w) for w in text1]) #finds the sum of length of words in text1
# Out:
# 999044

# %%
#finding the averege length of the word
sum([len(w) for w in text1])/len(text1)
# Out:
# 3.830411128023649

# %% [markdown]
# **Q12: Define a function called vocab_size(text) that has a single parameter for the text, and which  returns the vocabulary size of the text.**

# %%
def vocab_size(text):
    return len(set(text))

# %%
#passing text 1 to vocab_size
vocab_size(text1)
# Out:
# 19317

# %% [markdown]
# **Q13: Define a function percent(word, text) that calculates how often a given word occurs in a  text and expresses the result as a percentage.**

# %%
def percent(word, text):
    count=0
    for w in text:
        if w==word:
            count=count+1
    return count

# %%
print(percent('food', text1))
# Out:
# 14
